# %%
# show_matching_examples.py
"""
Affiche des exemples clairs de paires/clusters unifiés issus de step3_weighted_matching.py.
Idéal pour valider la qualité du matching sur profils marocains.
"""

import json
from pathlib import Path

def truncate(text, length=100):
    if not text:
        return "—"
    text = str(text).replace('\n', ' ').replace('\r', ' ')
    return (text[:length] + "...") if len(text) > length else text

def main():
    output_dir = Path("output")
    try:
        with open(output_dir / "unified_profiles.json", "r", encoding="utf-8") as f:
            unified = json.load(f)
    except FileNotFoundError:
        print("❌ Fichier 'unified_profiles.json' non trouvé. Exécute d'abord step3_weighted_matching.py.")
        return

    if not unified:
        print("⚠️ Aucune identité unifiée trouvée.")
        return

    print(f"🔍 Affichage de 5 clusters unifiés parmi {len(unified)} :\n")

    # Afficher les 5 premiers clusters (même si >2 profils)
    for idx, person in enumerate(unified[:5]):
        profiles = person["profiles"]
        print("=" * 90)
        print(f"🔸 Cluster {idx+1} | ID: {person['unified_id']} | {len(profiles)} profils")
        print("=" * 90)

        for p in profiles:
            plat = p["platform"].capitalize()
            name = p.get("fullName", "—")
            username = p.get("username", "—")
            email = p.get("email", "—")
            location = p.get("location", "—")
            bio = truncate(p.get("bio") or p.get("headline") or p.get("repo_descriptions", ""))

            print(f"\n➡️ {plat}:")
            print(f"   Nom complet : {name}")
            print(f"   Username    : @{username}")
            print(f"   Email       : {email}")
            print(f"   Localisation: {location}")
            print(f"   Bio         : {bio}")

        # Vérifier si c'est un vrai triplet (3 plateformes)
        platforms = {p["platform"] for p in profiles}
        if len(platforms) == 3:
            print("\n   🌟 Triplet complet détecté !")
        elif len(platforms) == 2:
            print(f"\n   🔗 Paire : {' ↔ '.join(sorted(platforms))}")
        print("\n")

    # Statistique rapide
    triplet_count = sum(1 for u in unified if len({p["platform"] for p in u["profiles"]}) == 3)
    pair_count = sum(1 for u in unified if len({p["platform"] for p in u["profiles"]}) == 2)
    print(f"📊 Résumé : {pair_count} paires | {triplet_count} triplets complets")

if __name__ == "__main__":
    main()
# Out:
# 🔍 Affichage de 5 clusters unifiés parmi 471 :
#
# ...
# 🔸 Cluster 1 | ID: person_00000 | 83 profils
# ...
#
# ➡️ Github:
#    Nom complet : Omar MHAIMDAT
#    Username    : @omarmhaimdat
#    Email       : omarmhaimdat@gmail.com
#    Localisation: morocco
#    Bio         : Data Scientist Software Engineer
#
# ➡️ Linkedin:
#    Nom complet : Omar Jadiani
#    Username    : @omar-jadiani-766aa3229
#    Email       : None
#    Localisation: other
#    Bio         : As a passionate Software Developer with a strong focus on building high performance mobile and web a...
#
# ➡️ Github:
#    Nom complet : Omar Jadiani
#    Username    : @OmarJ9
#    Email       : None
#    Localisation: morocco
#    Bio         : I am a passionate Software Developer
#
# ➡️ Linkedin:
#    Nom complet : OMAR Ait benhaddi
#    Username    : @omaraitbenhaddi
#    Email       : None
#    Localisation: morocco
# ...
